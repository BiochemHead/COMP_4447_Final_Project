# %%
import pandas as pd
from IPython.display import display, HTML

# %%
! cat cleaned_data.csv | tr -d '"'
# Out:
# CT - Segment 7: Goldhill to Copper Mountain,(['DIFFICULT, 4.7, 7, ['CO', Front Range']]),(['Leashed', [ 'Fall Colors, 'River/Creek', 'Views', Wildlife']]),('71', '29', '0', '0', '0', ['DIFFICULT', '0', '0', '0', '13', '88', '0', ']']),3,650,3,026,13.1,Point to Point,12,481,9,188,10,38
# CDT: Gold Hill to Georgia Pass (CO Sec. 28),(['INTERMEDIATE/DIFFICULT, 'None', 0, ['CO', Front Range']]),['Unknown'],('0', '0', '0', '0', '0', ['INTERMEDIATE/DIFFICULT', '0', '0', '33', '33', '33', '0', ']']),4,452,1,865,20.4,Point to Point,11,769,9,183,6,34
# CDT: Georgia Pass to Argentine Pass (CO Sec. 29),(['DIFFICULT, 4.0, 1, ['CO', Front Range']]),['Unknown'],('0', '100', '0', '0', '0', ['DIFFICULT', '0', '0', '0', '0', '100', '0', ']']),6,930,5,527,22.1,Point to Point,13,247,10,423,11,56
# MF Ranch Creek Road #142,(['EASY, 3.0, 1, ['CO', Front Range']]),(['Unknown', [ 'Views']]),('0', '0', '100', '0', '0', ['EASY', '100', '0', '0', '0', '0', '0', ']']),10,580,4.6,Point to Point,9,560,8,989,2,6
# ...

# %%
clean_df = pd.read_csv('cleaned_data.csv')
clean_df.columns = ['Trail Name', 'Difficult, Rating, No. Ratings, Area', 'Dog Info, Features', 'Star Ratings, Difficulty Rating, Percent Difficulty', 'elev gain', 'elev loss', 'trail_length', 'trail_type', 'elev_high', 'elev_low', 'avg_grade', 'max_grade']
display(HTML(clean_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Trail Name</th>
#       <th>Difficult, Rating, No. Ratings, Area</th>
#       <th>Dog Info, Features</th>
#       <th>Star Ratings, Difficulty Rating, Percent Difficulty</th>
#       <th>elev gain</th>
#       <th>elev loss</th>
#       <th>trail_length</th>
#       <th>trail_type</th>
#       <th>elev_high</th>
#       <th>elev_low</th>
#       <th>avg_grade</th>
#       <th>max_grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CDT: Gold Hill to Georgia Pass (CO Sec. 28)</td>
#       <td>("['INTERMEDIATE/DIFFICULT", 'None', 0, ['CO', "Front Range']"])</td>
#       <td>['Unknown']</td>
#       <td>('0', '0', '0', '0', '0', ['INTERMEDIATE/DIFFICULT', '0', '0', '33', '33', '33', '0', ']'])</td>
#       <td>4,452</td>
#       <td>1,865</td>
#       <td>20.4</td>
#       <td>Point to Point</td>
#       <td>11,769</td>
# ...
