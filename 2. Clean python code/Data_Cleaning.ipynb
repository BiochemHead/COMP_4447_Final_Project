# %% [markdown]
# # COMP 4447 Final Project

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# Read the hiking dataset pickle file  
df = pd.read_pickle("hike_project.pkl")

df.tail()
# Out:
#                       Trail Name Trail Length  \
# 3359      Cottonwood Creek Trail          7.4
# 3360             Homestead Trail          2.0
# 3361            Bear Creek Trail         14.9
# 3362  Washington Park Outer Loop          2.6
# 3363    Monument Park Trail West          2.2
#
#                                        Trail Difficulty Trail Rating  \
# 3359  [EASY/INTERMEDIATE\n 3.5 (4)\nAreas\nCO\nFront...   [ 3.5 (4)]
# 3360  [INTERMEDIATE\n 3.0 (1)\nAreas\nCO\nFront Rang...   [ 3.0 (1)]
# 3361  [EASY/INTERMEDIATE\n 4.3 (3)\nAreas\nCO\nFront...   [ 4.3 (3)]
# 3362   [EASY\n 4.0 (2)\nAreas\nCO\nFront Range\nDenver]   [ 4.0 (2)]
# 3363  [EASY\nBe the first to rate!\nAreas\nCO\nFront...           []
#
#      User Rate Number      Trail Type Elev_Up Elev_Down Highest Elevation  \
# 3359       [ 3.5 (4)]  Point to Point    687'       23'            6,923'
# 3360       [ 3.0 (1)]  Point to Point      4'      171'            6,789'
# 3361       [ 4.3 (3)]  Point to Point    806'      277'            5,804'
# 3362       [ 4.0 (2)]            Loop     33'       33'            5,328'
# 3363               []  Point to Point      2'       78'            6,068'
#
#      Lowest Elevation Average Grade Max Grade       Dogs and Features  \
# 3359           6,259'            2%        9%  [Leashed, River/Creek]
# 3360           6,622'            2%        4%               [Leashed]
# 3361           5,269'            1%       11%               [Leashed]
# 3362           5,307'            0%        4%         [Leashed, Lake]
# 3363           5,991'            1%        2%               [Unknown]
#
#                                             Stats Info.
# 3359  [  3.5 from 4 votes\n5 Star\n25%\n4 Star\n25%\...
# 3360  [  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 3361  [  4.3 from 3 votes\n5 Star\n67%\n4 Star\n0%\n...
# 3362  [  4.0 from 2 votes\n5 Star\n50%\n4 Star\n0%\n...
# 3363  [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...

# %%
# adding State, City, Area and Site 
df['State'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[3])
df['City'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[4])
df['Area'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[5] if len(x[0].split('\n')) > 5 else np.nan)
df['Site'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[6] if len(x[0].split('\n')) > 6 else np.nan)

# Specify the desired order of columns
columns = df.columns.tolist()
columns.remove('State')
columns.remove('City')
columns.remove('Area')
columns.remove('Site')
columns = columns[:1] + ['State'] + ['City'] + ['Area'] + ['Site'] + columns[1:]
df = df[columns]

df.sample(10)
# Out:
#                         Trail Name State         City              Area Site  \
# 2854      Lower Big Bluestem Trail    CO  Front Range           Boulder  NaN
# 1222    Lone Pine Creek Trail #951    CO  Front Range               NaN  NaN
# 86           Foothills North Trail    CO  Front Range           Boulder  NaN
# 1561        Cottonwood Creek Trail    CO  Front Range  Colorado Springs  NaN
# 1182                Foothills Path    CO  Front Range           Boulder  NaN
# 2823  Fern Meadow - Cragmoor Trail    CO  Front Range           Boulder  NaN
# 2395            Boulder Creek Path    CO  Front Range           Boulder  NaN
# 666          Foothills North Trail    CO  Front Range           Boulder  NaN
# 3270                Foothills Path    CO  Front Range           Boulder  NaN
# 2798               CU South Campus    CO  Front Range           Boulder  NaN
#
#      Trail Length                                   Trail Difficulty  \
# 2854          2.0  [EASY/INTERMEDIATE\n 3.3 (4)\nAreas\nCO\nFront...
# 1222          9.3   [INTERMEDIATE\n 3.3 (3)\nAreas\nCO\nFront Range]
# 86            1.2  [INTERMEDIATE/DIFFICULT\n 2.7 (3)\nAreas\nCO\n...
# 1561          7.4  [EASY/INTERMEDIATE\n 3.5 (4)\nAreas\nCO\nFront...
# 1182          4.1  [EASY\n 2.0 (1)\nAreas\nCO\nFront Range\nBoulder]
# 2823          1.6  [INTERMEDIATE/DIFFICULT\n 3.5 (2)\nAreas\nCO\n...
# 2395          8.2  [EASY/INTERMEDIATE\n 3.9 (12)\nAreas\nCO\nFron...
# 666           1.2  [INTERMEDIATE/DIFFICULT\n 2.7 (3)\nAreas\nCO\n...
# 3270          4.1  [EASY\n 2.0 (1)\nAreas\nCO\nFront Range\nBoulder]
# 2798          1.6  [EASY\n 3.3 (4)\nAreas\nCO\nFront Range\nBoulder]
#
#      Trail Rating User Rate Number      Trail Type Elev_Up Elev_Down  \
# 2854   [ 3.3 (4)]       [ 3.3 (4)]  Point to Point    397'       25'
# 1222   [ 3.3 (3)]       [ 3.3 (3)]  Point to Point  1,081'      346'
# 86     [ 2.7 (3)]       [ 2.7 (3)]  Point to Point    174'       91'
# 1561   [ 3.5 (4)]       [ 3.5 (4)]  Point to Point    687'       23'
# 1182   [ 2.0 (1)]       [ 2.0 (1)]  Point to Point     50'      116'
# 2823   [ 3.5 (2)]       [ 3.5 (2)]  Point to Point    850'       16'
# 2395  [ 3.9 (12)]      [ 3.9 (12)]  Point to Point     53'      559'
# 666    [ 2.7 (3)]       [ 2.7 (3)]  Point to Point    174'       91'
# 3270   [ 2.0 (1)]       [ 2.0 (1)]  Point to Point     50'      116'
# 2798   [ 3.3 (4)]       [ 3.3 (4)]  Point to Point     43'       11'
#
#      Highest Elevation Lowest Elevation Average Grade Max Grade  \
# 2854            5,877'           5,504'            4%       15%
# 1222            7,092'           6,232'            3%       17%
# 86              5,724'           5,550'            4%       16%
# 1561            6,923'           6,259'            2%        9%
# 1182            5,352'           5,236'            1%        4%
# 2823            6,611'           5,763'           11%       31%
# 2395            5,741'           5,193'            1%       10%
# 666             5,724'           5,550'            4%       16%
# 3270            5,352'           5,236'            1%        4%
# 2798            5,404'           5,361'            1%        2%
#
#                                       Dogs and Features  \
# 2854                     [Unknown, River/Creek · Views]
# 1222                                          [Unknown]
# 86          [Off-leash, Views · Wildflowers · Wildlife]
# 1561                             [Leashed, River/Creek]
# 1182                                          [Leashed]
# 2823       [Leashed, River/Creek · Views · Wildflowers]
# 2395  [Leashed, Birding · Fall Colors · River/Creek ...
# 666         [Off-leash, Views · Wildflowers · Wildlife]
# 3270                                          [Leashed]
# 2798  [Leashed, Birding · Fall Colors · Lake · River...
#
#                                             Stats Info.
# 2854  [  3.3 from 4 votes\n5 Star\n0%\n4 Star\n50%\n...
# 1222  [  3.3 from 3 votes\n5 Star\n0%\n4 Star\n33%\n...
# 86    [  2.7 from 3 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 1561  [  3.5 from 4 votes\n5 Star\n25%\n4 Star\n25%\...
# 1182  [  2.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 2823  [  3.5 from 2 votes\n5 Star\n0%\n4 Star\n50%\n...
# 2395  [  3.9 from 12 votes\n5 Star\n25%\n4 Star\n42%...
# 666   [  2.7 from 3 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 3270  [  2.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 2798  [  3.3 from 4 votes\n5 Star\n0%\n4 Star\n50%\n...

# %%
# Data cleaning
# Cleaning Trail rating, User rate number, and renaming User rate number to user review 
if not np.issubdtype(df['Trail Rating'].dtype, np.dtype(str).type):
    df['Trail Rating'] = df['Trail Rating'].astype(str)
df['Trail Rating'] = pd.to_numeric(df['Trail Rating'].str.extract('(\d+\.\d+)')[0], errors='coerce')

if not np.issubdtype(df['User Rate Number'].dtype, np.dtype(str).type):
    df['User Rate Number'] = df['User Rate Number'].astype(str)
df['User Rate Number'] = df['User Rate Number'].str.extract('\((\d+)\)')[0]

df = df.rename(columns={'User Rate Number': 'User Review'})


# Cleaninbg Trail Difficulty and mappping difficulty number 
df['Trail Difficulty'] = df['Trail Difficulty'].apply(lambda x: x[0].split()[0])

# Difficulty mapping
difficulty_map = {
    'EASY': 1,
    'EASY/INTERMEDIATE': 2,
    'INTERMEDIATE': 3,
    'INTERMEDIATE/DIFFICULT': 4,
    'DIFFICULT': 5
}

# Create and sort the Difficulty Number column 
df['Difficulty Number'] = df['Trail Difficulty'].map(difficulty_map)

columns = df.columns.tolist()
columns.remove('Difficulty Number')
columns = columns[:7] + ['Difficulty Number'] + columns[7:]
df = df[columns]

# Cleaning Dog and Features, and sort columns 
df['Features'] = df['Dogs and Features'].apply(lambda x: x[1] if len(x) > 1 else np.nan)

columns = df.columns.tolist()
columns.remove('Features')
columns = columns[:18] + ['Features'] + columns[18:]
df = df[columns]

df['Dogs and Features'] = df['Dogs and Features'].apply(lambda x: x[0].split()[0])
df['Dogs and Features'] = df['Dogs and Features'].replace("Unknown", np.nan)
df = df.rename(columns={'Dogs and Features': 'Dogs'})


df.sample(10)
# Out:
#                                        Trail Name State         City  \
# 257          Niwot Loop - Niwot High School Trail    CO  Front Range
# 1020                          Dark Mountain Trail    CO  Front Range
# 2650                                  Skunk Creek    CO  Front Range
# 3171                 Fern Meadow - Cragmoor Trail    CO  Front Range
# 986   CT - Segment 7: Goldhill to Copper Mountain    CO  Front Range
# 3091                           Boulder Creek Path    CO  Front Range
# 1571                  East Blue River Trail #9104    CO  Front Range
# 123                           Elk Horn Trail #925    CO  Front Range
# 1136                          Dark Mountain Trail    CO  Front Range
# 1372                          Anne U. White Trail    CO  Front Range
#
#                               Area Site Trail Length        Trail Difficulty  \
# 257                        Boulder  NaN          2.3                    EASY
# 1020  Rocky Mountain National Park  NaN          1.7            INTERMEDIATE
# 2650                       Boulder  NaN          1.6                    EASY
# 3171                       Boulder  NaN          1.6  INTERMEDIATE/DIFFICULT
# 986                            NaN  NaN         13.1               DIFFICULT
# 3091                       Boulder  NaN          8.2       EASY/INTERMEDIATE
# 1571                           NaN  NaN          1.2                    EASY
# 123                            NaN  NaN          3.5               DIFFICULT
# 1136  Rocky Mountain National Park  NaN          1.7            INTERMEDIATE
# 1372                       Boulder  NaN          1.7       EASY/INTERMEDIATE
#
#       Difficulty Number  Trail Rating User Review      Trail Type Elev_Up  \
# 257                   1           3.5           2  Point to Point     14'
# 1020                  3           4.0           1  Point to Point      1'
# 2650                  1           2.0           1  Point to Point     30'
# 3171                  4           3.5           2  Point to Point    850'
# 986                   5           4.7           7  Point to Point  3,650'
# 3091                  2           3.9          12  Point to Point     53'
# 1571                  1           NaN         NaN  Point to Point     60'
# 123                   5           NaN         NaN  Point to Point  2,070'
# 1136                  3           4.0           1  Point to Point      1'
# 1372                  2           4.5           6  Point to Point    454'
#
#      Elev_Down Highest Elevation Lowest Elevation Average Grade Max Grade  \
# 257       258'            5,299'           5,044'            2%        8%
# 1020    1,268'            9,498'           8,230'           14%       62%
# 2650       20'            5,283'           5,255'            1%        2%
# 3171       16'            6,611'           5,763'           11%       31%
# 986     3,026'           12,481'           9,188'           10%       38%
# 3091      559'            5,741'           5,193'            1%       10%
# 1571       13'            8,606'           8,552'            1%        4%
# 123        22'           11,351'           9,300'           11%       35%
# 1136    1,268'            9,498'           8,230'           14%       62%
# 1372        6'            6,520'           6,072'            5%       18%
#
#            Dogs                                           Features  \
# 257     Leashed  Birding · Fall Colors · River/Creek · Views · ...
# 1020         No  Birding · Fall Colors · River/Creek · Views · ...
# 2650  Off-leash                                        River/Creek
# 3171    Leashed                  River/Creek · Views · Wildflowers
# 986     Leashed       Fall Colors · River/Creek · Views · Wildlife
# 3091    Leashed  Birding · Fall Colors · River/Creek · Swimming...
# 1571        NaN                                                NaN
# 123         NaN                                                NaN
# 1136         No  Birding · Fall Colors · River/Creek · Views · ...
# 1372    Leashed                                                NaN
#
#                                             Stats Info.
# 257   [  3.5 from 2 votes\n5 Star\n0%\n4 Star\n50%\n...
# 1020  [  4.0 from 1 vote\n5 Star\n0%\n4 Star\n100%\n...
# 2650  [  2.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 3171  [  3.5 from 2 votes\n5 Star\n0%\n4 Star\n50%\n...
# 986   [  4.7 from 7 votes\n5 Star\n71%\n4 Star\n29%\...
# 3091  [  3.9 from 12 votes\n5 Star\n25%\n4 Star\n42%...
# 1571  [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 123   [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 1136  [  4.0 from 1 vote\n5 Star\n0%\n4 Star\n100%\n...
# 1372  [  4.5 from 6 votes\n5 Star\n67%\n4 Star\n17%\...

# %%
# Showing Datatypes 
df.dtypes
# Out:
# Trail Name            object
# State                 object
# City                  object
# Area                  object
# Site                  object
# Trail Length          object
# Trail Difficulty      object
# Difficulty Number      int64
# Trail Rating         float64
# User Review           object
# Trail Type            object
# Elev_Up               object
# Elev_Down             object
# Highest Elevation     object
# Lowest Elevation      object
# Average Grade         object
# Max Grade             object
# Dogs                  object
# Features              object
# Stats Info.           object
# dtype: object

# %%
# Correcting DataTypes 
df['Trail Length'] = df['Trail Length'].astype(float)
df['Elev_Up'] = df['Elev_Up'].str.replace("'", "").str.replace(",", "").astype(float)
df['Elev_Down'] = df['Elev_Down'].str.replace("'", "").str.replace(",", "").astype(float)
df['Highest Elevation'] = df['Highest Elevation'].str.replace("'", "").str.replace(",", "").astype(float)
df['Lowest Elevation'] = df['Lowest Elevation'].str.replace("'", "").str.replace(",", "").astype(float)
df['Average Grade'] = df['Average Grade'].str.strip('%').astype(float) / 100
df['Max Grade'] = df['Max Grade'].str.strip('%').astype(float) / 100
df['User Review'] = df['User Review'].astype("Int64")

df.dtypes
# Out:
# Trail Name            object
# State                 object
# City                  object
# Area                  object
# Site                  object
# Trail Length         float64
# Trail Difficulty      object
# Difficulty Number      int64
# Trail Rating         float64
# User Review            Int64
# Trail Type            object
# Elev_Up              float64
# Elev_Down            float64
# Highest Elevation    float64
# Lowest Elevation     float64
# Average Grade        float64
# Max Grade            float64
# Dogs                  object
# Features              object
# Stats Info.           object
# dtype: object

# %%
df.drop(columns='Stats Info.', inplace=True)

# %%
# Splitting Features Contains into separate Columns
all_features = ['Birding', 'Fall Colors', 'River/Creek', 'Views', 'Wildflowers', 'Spring',
                  'Geological Significance', 'Swimming', 'Lake', 'Wildlife']
for i in all_features:
    df[i] = df['Features'].str.contains(i)

# Replacing all Features NaN values with False 
df['Birding'] = df['Birding'].fillna(False)
df['Fall Colors'] = df['Fall Colors'].fillna(False)
df['River/Creek'] = df['River/Creek'].fillna(False)
df['Views'] = df['Views'].fillna(False)
df['Wildflowers'] = df['Wildflowers'].fillna(False)
df['Wildlife'] = df['Wildlife'].fillna(False)
df['Spring'] = df['Spring'].fillna(False)
df['Geological Significance'] = df['Geological Significance'].fillna(False)
df['Swimming'] = df['Swimming'].fillna(False)
df['Lake'] = df['Lake'].fillna(False)
   
df.iloc[:,18:].sample(25)
# Out:
#                                                Features  Birding  Fall Colors  \
# 2150                                                NaN    False        False
# 3051  Birding · Fall Colors · River/Creek · Views · ...     True         True
# 1851                                        River/Creek    False        False
# 1065                                                NaN    False        False
# 1676                                                NaN    False        False
# 1689                                                NaN    False        False
# 200               Lake · Views · Wildflowers · Wildlife    False        False
# 1110                                                NaN    False        False
# 2687                                                NaN    False        False
# 2058                     Views · Wildflowers · Wildlife    False        False
# 1109                                                NaN    False        False
# 2144                                               Lake    False        False
# 3127                                        River/Creek    False        False
# 2936  Birding · Fall Colors · River/Creek · Views · ...     True         True
# 2805                                                NaN    False        False
# 927                                                 NaN    False        False
# 3177                                                NaN    False        False
# 1972       Fall Colors · River/Creek · Views · Wildlife    False         True
# 1309                                Fall Colors · Views    False         True
# 63                                                  NaN    False        False
# 3056                                        River/Creek    False        False
# 21                                                  NaN    False        False
# 2894                                                NaN    False        False
# 570                                               Views    False        False
# 1973                                                NaN    False        False
#
#       River/Creek  Views  Wildflowers  Spring  Geological Significance  \
# 2150        False  False        False   False                    False
# 3051         True   True         True   False                    False
# 1851         True  False        False   False                    False
# 1065        False  False        False   False                    False
# 1676        False  False        False   False                    False
# 1689        False  False        False   False                    False
# 200         False   True         True   False                    False
# 1110        False  False        False   False                    False
# 2687        False  False        False   False                    False
# 2058        False   True         True   False                    False
# 1109        False  False        False   False                    False
# 2144        False  False        False   False                    False
# 3127         True  False        False   False                    False
# 2936         True   True         True   False                    False
# 2805        False  False        False   False                    False
# 927         False  False        False   False                    False
# 3177        False  False        False   False                    False
# 1972         True   True        False   False                    False
# 1309        False   True        False   False                    False
# 63          False  False        False   False                    False
# 3056         True  False        False   False                    False
# 21          False  False        False   False                    False
# 2894        False  False        False   False                    False
# 570         False   True        False   False                    False
# 1973        False  False        False   False                    False
#
#       Swimming   Lake  Wildlife
# 2150     False  False     False
# 3051     False  False      True
# 1851     False  False     False
# 1065     False  False     False
# 1676     False  False     False
# 1689     False  False     False
# 200      False   True      True
# 1110     False  False     False
# 2687     False  False     False
# 2058     False  False      True
# 1109     False  False     False
# 2144     False   True     False
# 3127     False  False     False
# 2936     False  False      True
# 2805     False  False     False
# 927      False  False     False
# 3177     False  False     False
# 1972     False  False      True
# 1309     False  False     False
# 63       False  False     False
# 3056     False  False     False
# 21       False  False     False
# 2894     False  False     False
# 570      False  False     False
# 1973     False  False     False

# %%
df.drop(columns='Features', inplace=True)
df.iloc[:,15:].sample(5)
# Out:
#       Average Grade  Max Grade       Dogs  Birding  Fall Colors  River/Creek  \
# 647            0.05       0.13    Leashed    False        False         True
# 67             0.05       0.13    Leashed    False        False         True
# 475            0.09       0.13  Off-leash    False        False        False
# 737            0.01       0.02  Off-leash    False        False        False
# 1255           0.04       0.11        NaN    False        False        False
#
#       Views  Wildflowers  Spring  Geological Significance  Swimming   Lake  \
# 647   False         True   False                     True     False  False
# 67    False         True   False                     True     False  False
# 475   False        False   False                    False     False  False
# 737   False        False   False                    False     False  False
# 1255  False        False   False                    False     False  False
#
#       Wildlife
# 647       True
# 67        True
# 475      False
# 737      False
# 1255     False

# %%
df.dtypes
# Out:
# Trail Name                  object
# State                       object
# City                        object
# Area                        object
# Site                        object
# Trail Length               float64
# Trail Difficulty            object
# Difficulty Number            int64
# Trail Rating               float64
# User Review                  Int64
# Trail Type                  object
# Elev_Up                    float64
# Elev_Down                  float64
# Highest Elevation          float64
# Lowest Elevation           float64
# Average Grade              float64
# Max Grade                  float64
# Dogs                        object
# Birding                       bool
# Fall Colors                   bool
# River/Creek                   bool
# Views                         bool
# Wildflowers                   bool
# Spring                        bool
# Geological Significance       bool
# Swimming                      bool
# Lake                          bool
# Wildlife                      bool
# dtype: object

# %%
df.to_pickle("hike_project_cln_data.pkl")
