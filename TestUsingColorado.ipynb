# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from IPython.display import display, HTML

# %%
# GETS LIST OF TRAIL LINKS

driver = webdriver.Chrome()
driver.get('https://www.hikingproject.com/directory/8007418/colorado')
driver.implicitly_wait(5)
for i in range(10):
    try:
        load_more = driver.find_element(By.ID, "load-more-trails")
        action = ActionChains(driver)
        action.click(on_element = load_more)
        action.perform()
        i += 1
    except NoSuchElementException:
        break
        
rows=driver.find_elements(By.CLASS_NAME, "text-black")
for row in rows:
    print(row.text)
# Out:
# Dream Lake
# Royal Arch
# Alberta Falls
# Bear Lake
# Gem Lake
# Hanging Lake
# Trail Ridge Road Summit
# The Loch
# High Dune
# Chasm Lake and The Diamond
# Ouzel Falls
# Maroon Bells
# Crater Lake and Lone Eagle Peak
# Lily Lake
# Chasm Falls and Old Fall River Road
# Painted Wall Overlook
# Blue Lakes
# Star Dune
# Red Rocks
# Balcony House
# Otto's Bathtub
# Snowmass Lake
# Alluvial Fan
# Cliff Palace
# Rattlesnake Arch
# Warner Point
# Adams Falls
# Castlewood Dam
# Bighorn Sheep Viewing - Sheep Lakes
# Tundra Communities Trail (aka Toll Memorial Trail)
# Cub Lake
# Lake Isabelle
# Long Lake
# Pulpit Rock Overlook
# Rock House
# East Inlet Vista
# Sentinel Point Summit
# Conundrum Hot Springs
# Marion Mine
# Zodiac Ridge
# Snow Pass
# Book Cliffs View
# Coke Ovens Overlook
# Long House
# Sky Pond
# Great camping spot
# Liberty Cap
# Horsetooth Falls
# Petroglyph Panel at Petroglyph Point
# Beaver Lake
# Far View Sites
# Coyote Valley
# Zapata Falls
# Spruce Tree House
# West Creek Falls
# Rainbow Lake
# Bridal Veil Falls
# Astronomy in the Park
# Kissing Camels
# Holzwarth Historic Site
# Upper Boulder Lake
# Lulu City
# Beaver Viewing at the Beaver Boardwalk
# Lookout Peak Trail
# 4.9 mi • 1,948' Up • 1,947' Down
# Longs Peak - Keyhole Route
# 14.0 mi • 5,241' Up • 5,231' Down
# Timber Lake Trail
# 9.3 mi • 2,012' Up • 2,012' Down
# Chasm Lake
# 8.2 mi • 2,766' Up • 2,766' Down
# Colorado Trail: Georgia Pass to Breckenridge
# 20.3 mi • 4,353' Up • 1,776' Down
# Green Mountain West Ridge
# 3.9 mi • 633' Up • 634' Down
# Hogback Ridge Loop
# 2.1 mi • 740' Up • 739' Down
# Longs Peak Valley Loop
# 23.2 mi • 5,129' Up • 5,150' Down
# Almagre Mountain via FSR 379
# 15.8 mi • 2,535' Up • 2,535' Down
# #1CT - Segment 7: Goldhill to Copper Mountain
# #2CDT: Gold Hill to Georgia Pass (CO Sec. 28)
# #3CDT: Georgia Pass to Argentine Pass (CO Sec. 29)
# #4MF Ranch Creek Road #142
# #5Lone Pine Creek Trail #951
# #6East Blue River Trail #9104
# #7Bushee Creek Trail #9104.1
# #8Elk Horn Trail #925
# #9Piney Creek Trail
# #10OT Loop
# #11Fern Canyon Trail
# #12North Fork Shanahan Trail
# #13Lower Big Bluestem Trail
# #14South Fork Shanahan Trail
# #15CU South Campus
# #16South Boulder Creek Trail
# #17Chapman Drive
# #18Boulder Creek Path
# #19Bear Creek Path
# #203 Bar Loop
# #213 Bar Connector
# #22Happy Canyon Trail
# #23Foothills Path
# #24Goose Creek Path
# #25Cottonwood Trail
# #26Niwot Loop - Niwot High School Trail
# #27Dry Creek Trail
# #28Foothills Bench Trail
# #29Foothills North Trail
# #30Hogback Ridge Trail
# #31Dodd Reservoir Trail
# #32Bobolink Trail
# #33East Boulder Community Center Connector
# #34CR 83J
# #35Dark Mountain Trail
# #36South Lateral Moraine Trail
# #37Utility Area Access Trail
# #38Bear Creek - Greenway Trail Connector
# #39Anne U. White Trail
# #40Fern Meadow - Cragmoor Trail
# #41Skunk Creek
# #42Centennial Trail
# #43Pearl Parkway Path
# #44Wonderland Creek Path
# #45Fourmile Creek Trail
# #46Elmer's Twomile Trail
# #47Plymouth Creek Trail
# #48Red Mesa Loop
# #49Golden Eagle Trail
# #50Plymouth Mountain Trail
# #51Cheesman Park
# #52FSR 379
# #53East Harvard Gulch Trail
# #54Cottonwood Creek Trail
# #55Homestead Trail
# #56Bear Creek Trail
# #57Washington Park Outer Loop
# #58Monument Park Trail West
# #59Homesteader Trail
# #60Plymouth Mountain Lookout
# #61Meadowlark Trail
# #62Ralston Creek Trail
# #63Greyrock Meadows Trail #947
# #64Greyrock Trail #946
# #65Donner Pass Trail #926
# #66Old Flowers Road FR 152
# #67Berkeley Lake Park Path
# #68Standley Lake South Shore Outer Loop
# #69Rocky Mountain Greenway Trail
# #70Rattlesnake Gulch Trail
# Dec 6, 2014 near Crested…, CO
# Jan 8, 2015 near Estes Park, CO
# Jan 30, 2015 near Grand Lake, CO
# Feb 4, 2015 near Vail, CO
# Apr 14, 2015 near Granby, CO
# Sep 27, 2015 near Snowmas…, CO
# Dec 8, 2015 near Estes Park, CO
# May 20, 2016 near Estes Park, CO

# %%
# REFINES TRAIL LINKS

url=[]
for row in rows:
    test=row.get_attribute('href')
    if test != None:
        url.append(test)
print(url)
# Out:
# ['https://www.hikingproject.com/trail/7011020/ct-segment-7-goldhill-to-copper-mountain', 'https://www.hikingproject.com/trail/7016057/cdt-gold-hill-to-georgia-pass-co-sec-28', 'https://www.hikingproject.com/trail/7016058/cdt-georgia-pass-to-argentine-pass-co-sec-29', 'https://www.hikingproject.com/trail/7038057/mf-ranch-creek-road-142', 'https://www.hikingproject.com/trail/7056548/lone-pine-creek-trail-951', 'https://www.hikingproject.com/trail/7057006/east-blue-river-trail-9104', 'https://www.hikingproject.com/trail/7057053/bushee-creek-trail-91041', 'https://www.hikingproject.com/trail/7057945/elk-horn-trail-925', 'https://www.hikingproject.com/trail/7075584/piney-creek-trail', 'https://www.hikingproject.com/trail/7092570/ot-loop', 'https://www.hikingproject.com/trail/7000072/fern-canyon-trail', 'https://www.hikingproject.com/trail/7000083/north-fork-shanahan-trail', 'https://www.hikingproject.com/trail/7000100/lower-big-bluestem-trail', 'https://www.hikingproject.com/trail/7000105/south-fork-shanahan-trail', 'https://www.hikingproject.com/trail/7001573/cu-south-campus', 'https://www.hikingproject.com/trail/7001575/south-boulder-creek-trail', 'https://www.hikingproject.com/trail/7001630/chapman-drive', 'https://www.hikingproject.com/trail/7001631/boulder-creek-path', 'https://www.hikingproject.com/trail/7001632/bear-creek-path', 'https://www.hikingproject.com/trail/7093107/3-bar-loop', 'https://www.hikingproject.com/trail/7093108/3-bar-connector', 'https://www.hikingproject.com/trail/7104102/happy-canyon-trail', 'https://www.hikingproject.com/trail/7001633/foothills-path', 'https://www.hikingproject.com/trail/7001634/goose-creek-path', 'https://www.hikingproject.com/trail/7001657/cottonwood-trail', 'https://www.hikingproject.com/trail/7001661/niwot-loop-niwot-high-school-trail', 'https://www.hikingproject.com/trail/7004621/dry-creek-trail', 'https://www.hikingproject.com/trail/7004872/foothills-bench-trail', 'https://www.hikingproject.com/trail/7004873/foothills-north-trail', 'https://www.hikingproject.com/trail/7005386/hogback-ridge-trail', 'https://www.hikingproject.com/trail/7009450/dodd-reservoir-trail', 'https://www.hikingproject.com/trail/7018568/bobolink-trail', 'https://www.hikingproject.com/trail/7018569/east-boulder-community-center-connector', 'https://www.hikingproject.com/trail/7083547/cr-83j', 'https://www.hikingproject.com/trail/7000293/dark-mountain-trail', 'https://www.hikingproject.com/trail/7000535/south-lateral-moraine-trail', 'https://www.hikingproject.com/trail/7000562/utility-area-access-trail', 'https://www.hikingproject.com/trail/7003683/bear-creek-greenway-trail-connector', 'https://www.hikingproject.com/trail/7089709/anne-u-white-trail', 'https://www.hikingproject.com/trail/7093182/fern-meadow-cragmoor-trail', 'https://www.hikingproject.com/trail/7100686/skunk-creek', 'https://www.hikingproject.com/trail/7100687/centennial-trail', 'https://www.hikingproject.com/trail/7100689/pearl-parkway-path', 'https://www.hikingproject.com/trail/7100690/wonderland-creek-path', 'https://www.hikingproject.com/trail/7100691/fourmile-creek-trail', 'https://www.hikingproject.com/trail/7100692/elmers-twomile-trail', 'https://www.hikingproject.com/trail/7005056/plymouth-creek-trail', 'https://www.hikingproject.com/trail/7005057/red-mesa-loop', 'https://www.hikingproject.com/trail/7005058/golden-eagle-trail', 'https://www.hikingproject.com/trail/7005059/plymouth-mountain-trail', 'https://www.hikingproject.com/trail/7020640/cheesman-park', 'https://www.hikingproject.com/trail/7033772/fsr-379', 'https://www.hikingproject.com/trail/7054854/east-harvard-gulch-trail', 'https://www.hikingproject.com/trail/7056654/cottonwood-creek-trail', 'https://www.hikingproject.com/trail/7056656/homestead-trail', 'https://www.hikingproject.com/trail/7073054/bear-creek-trail', 'https://www.hikingproject.com/trail/7084094/washington-park-outer-loop', 'https://www.hikingproject.com/trail/7093676/monument-park-trail-west', 'https://www.hikingp ...

# %%
# EXTRACTS NECESSARY DATA FROM EACH TRAIL PAGE

test_list = []
for link in url:
    driver.get(link)
    name = driver.find_element(By.ID, "trail-title")
    difficulty = driver.find_elements(By.CLASS_NAME, 'trail-subheader')
    difficult = [d.text for d in difficulty]
    rating = driver.find_elements(By.CSS_SELECTOR, '#title-stars > span.small')
    site_rating = [r.text for r in rating]
    dogs = driver.find_elements(By.CSS_SELECTOR, '#trail-text > div:nth-child(2) > h3 > span')
    dog_feature = [d.text for d in dogs]
    description = driver.find_elements(By.CSS_SELECTOR, '#trail-text > div:nth-child(4)')
    stats = driver.find_elements(By.CLASS_NAME, 'stat-box')
    elev_up= driver.find_element(By.CSS_SELECTOR, "#trail-stats-bar > div:nth-child(3) > h3:nth-child(1) > span.imperial")
    elev_down= driver.find_element(By.CSS_SELECTOR, '#trail-stats-bar > div:nth-child(3) > h3:nth-child(3) > span.imperial')
    trail_length= driver.find_element(By.CSS_SELECTOR,'#trail-stats-bar > div.stat-block.ml-2.mr-1.mt-1 > span.imperial > h3')
    trail_type = driver.find_element(By.CSS_SELECTOR,'#trail-stats-bar > div.stat-block.ml-2.mr-1.mt-1 > h3')
    elev_high = driver.find_element(By.CSS_SELECTOR, '#trail-stats-bar > div:nth-child(2) > h3:nth-child(1) > span.imperial')
    elev_low = driver.find_element(By.CSS_SELECTOR, '#trail-stats-bar > div:nth-child(2) > h3:nth-child(3) > span.imperial')
    avg_grade = driver.find_element(By.CSS_SELECTOR, '#trail-stats-bar > div.stat-block.ml-1.mt-1 > h3:nth-child(1)')
    max_grade = driver.find_element(By.CSS_SELECTOR, '#trail-stats-bar > div.stat-block.ml-1.mt-1 > h3:nth-child(3)')
    test_list.append([name.text, difficult, site_rating, dog_feature, [stat.text for stat in stats], elev_up.text, elev_down.text, trail_length.text, trail_type.text, elev_high.text, elev_low.text, avg_grade.text, max_grade.text])
    print(link + ' complete')
# Out:
# https://www.hikingproject.com/trail/7011020/ct-segment-7-goldhill-to-copper-mountain complete
# https://www.hikingproject.com/trail/7016057/cdt-gold-hill-to-georgia-pass-co-sec-28 complete
# https://www.hikingproject.com/trail/7016058/cdt-georgia-pass-to-argentine-pass-co-sec-29 complete
# https://www.hikingproject.com/trail/7038057/mf-ranch-creek-road-142 complete
# https://www.hikingproject.com/trail/7056548/lone-pine-creek-trail-951 complete
# https://www.hikingproject.com/trail/7057006/east-blue-river-trail-9104 complete
# https://www.hikingproject.com/trail/7057053/bushee-creek-trail-91041 complete
# https://www.hikingproject.com/trail/7057945/elk-horn-trail-925 complete
# https://www.hikingproject.com/trail/7075584/piney-creek-trail complete
# https://www.hikingproject.com/trail/7092570/ot-loop complete
# https://www.hikingproject.com/trail/7000072/fern-canyon-trail complete
# https://www.hikingproject.com/trail/7000083/north-fork-shanahan-trail complete
# https://www.hikingproject.com/trail/7000100/lower-big-bluestem-trail complete
# https://www.hikingproject.com/trail/7000105/south-fork-shanahan-trail complete
# https://www.hikingproject.com/trail/7001573/cu-south-campus complete
# https://www.hikingproject.com/trail/7001575/south-boulder-creek-trail complete
# https://www.hikingproject.com/trail/7001630/chapman-drive complete
# https://www.hikingproject.com/trail/7001631/boulder-creek-path complete
# https://www.hikingproject.com/trail/7001632/bear-creek-path complete
# https://www.hikingproject.com/trail/7093107/3-bar-loop complete
# https://www.hikingproject.com/trail/7093108/3-bar-connector complete
# https://www.hikingproject.com/trail/7104102/happy-canyon-trail complete
# https://www.hikingproject.com/trail/7001633/foothills-path complete
# https://www.hikingproject.com/trail/7001634/goose-creek-path complete
# https://www.hikingproject.com/trail/7001657/cottonwood-trail complete
# https://www.hikingproject.com/trail/7001661/niwot-loop-niwot-high-school-trail complete
# https://www.hikingproject.com/trail/7004621/dry-creek-trail complete
# https://www.hikingproject.com/trail/7004872/foothills-bench-trail complete
# https://www.hikingproject.com/trail/7004873/foothills-north-trail complete
# https://www.hikingproject.com/trail/7005386/hogback-ridge-trail complete
# https://www.hikingproject.com/trail/7009450/dodd-reservoir-trail complete
# https://www.hikingproject.com/trail/7018568/bobolink-trail complete
# https://www.hikingproject.com/trail/7018569/east-boulder-community-center-connector complete
# https://www.hikingproject.com/trail/7083547/cr-83j complete
# https://www.hikingproject.com/trail/7000293/dark-mountain-trail complete
# https://www.hikingproject.com/trail/7000535/south-lateral-moraine-trail complete
# https://www.hikingproject.com/trail/7000562/utility-area-access-trail complete
# https://www.hikingproject.com/trail/7003683/bear-creek-greenway-trail-connector complete
# https://www.hikingproject.com/trail/7089709/anne-u-white-trail complete
# https://www.hikingproject.com/trail/7093182/fern-meadow-cragmoor-trail complete
# https://www.hikingproject.com/trail/7100686/skunk-creek complete
# https://www.hikingproject.com/trail/7100687/centennial-trail complete
# https://www.hikingproject.com/trail/7100689/pearl-parkway-path complete
# https://www.hikingproject.com/trail/7100690/wonderland-creek-path complete
# https://www.hikingproject.com/trail/7100691/fourmile-creek-trail complete
# https://www.hikingproject.com/trail/7100692/elmers-twomile-trail complete
# https://www.hikingproject.com/trail/7005056/plymouth-creek-trail complete
# https://www.hikingproject.com/trail/7005057/red-mesa-loop complete
# https://www.hikingproject.com/trail/7005058/golden-eagle-trail complete
# https://www.hikingproject.com/trail/7005059/plymouth-mountain-trail complete
# https://www.hikingproject.com/trail/7020640/cheesman-park complete
# https://www.hikingproject.com/trail/7033772/fsr-379 complete
# https://www.hikingproject.com/trail/7054854/east-harvard-gulch-trail complete
# https://www.hikingproject.com/trail/7056654/cottonwood-creek-trail complete
# https://www.hikingproject.com/trail/7056656/homestead-trail complete
# https://www.hikingproject.com/trail/7073054/bear-creek-trail complete
# https://www.hikingproject.com/trail/7084094/washington-park-outer-loop complete
# https://www.hikingproject.com/trail/7093676/monument-park-trail-west complete
# https://www.hikingproject.com/trail/7005060/homesteader-trail complete
# https://www.hikingproject.com/trail/7005061/plymouth-mountain-lookout complete
# https://www.hikingproject.com/trail/7005062/meadowlark-trail complete
# https://www.hikingproject.com/trail/7005381/ralston-creek-trail complete
# https://www.hikingproject.com/trail/7028735/greyrock-meadows-trail-947 complete
# https://www.hikingproject.com/trail/7029852/greyrock-trail-946 complete
# https://www.hikingproject.com/trail/7033588/donner-pass-trail-926 complete
# https://www.hikingproject.com/trail/7038256/old-flowers-road-fr-152 complete
# https://www.hikingproject.com/trail/7074179/berkeley-lake-park-path complete
# https://www.hikingproject.com/trail/7074704/standley-lake-south-shore-outer-loop complete
# https://www.hikingproject.com/trail/7074718/rocky-mountain-greenway-trail complete
# https://www.hikingproject.com/trail/7084361/rattlesnake-gulch-trail complete

# %%
# CONVERTS TO DATAFRAME

test_df = pd.DataFrame(data=test_list, columns=['Name','Site Diff Rating', 'Rating', 'Dogs and Features', 'Stats Breakdown', 'Elev_Up', 'Elev_Down', 'Trail Length', 'Trail Type', 'Highest Elevation', 'Lowest Elevation', 'Average Grade', 'Max Grade'])
test_df2 = test_df.replace('\n', ' ', regex=True)
display(HTML(test_df2.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Site Diff Rating</th>
#       <th>Rating</th>
#       <th>Dogs and Features</th>
#       <th>Stats Breakdown</th>
#       <th>Elev_Up</th>
#       <th>Elev_Down</th>
#       <th>Trail Length</th>
#       <th>Trail Type</th>
#       <th>Highest Elevation</th>
#       <th>Lowest Elevation</th>
#       <th>Average Grade</th>
#       <th>Max Grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CT - Segment 7: Goldhill to Copper Mountain</td>
#       <td>[DIFFICULT\n 4.7 (7)\nAreas\nCO\nFront Range]</td>
#       <td>[ 4.7 (7)]</td>
#       <td>[Leashed, Fall Colors · River/Creek · Views · Wildlife]</td>
#       <td>[  4.7 from 7 votes\n5 Star\n71%\n4 Star\n29%\n3 Star\n0%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#1 in Front Range\n#141 in Colorado\n#838 Overall\n24 Views Last Month\n11,950 Since Nov 6, 2015, DIFFICULT\n0%\n0%\n0%\n13%\n88%\n0%]</td>
#       <td>3,650'</td>
#       <td>3,026'</td>
#       <td>13.1</td>
#       <td>Point to Point</td>
#       <td>12,481'</td>
#       <td>9,188'</td>
#       <td>10%</td>
#       <td>38%</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>CDT: Gold Hill to Georgia Pass (CO Sec. 28)</td>
#       <td>[INTERMEDIATE/DIFFICULT\nBe the first to rate!\nAreas\nCO\nFront Range]</td>
#       <td>[]</td>
#       <td>[Unknown]</td>
#       <td>[  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3 Star\n0%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#10 in Front Range\n#3,644 in Colorado\n#46,785 Overall\n2 Views Last Month\n585 Since Jul 13, 2016, INTERMEDIATE/DIFFICULT\n0%\n0%\n33%\n33%\n33%\n0%]</td>
#       <td>4,452'</td>
#       <td>1,865'</td>
#       <td>20.4</td>
#       <td>Point to Point</td>
#       <td>11,769'</td>
#       <td>9,183'</td>
#       <td>6%</td>
#       <td>34%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CDT: Georgia Pass to Argentine Pass (CO Sec. 29)</td>
#       <td>[DIFFICULT\n 4.0 (1)\nAreas\nCO\nFront Range]</td>
#       <td>[ 4.0 (1)]</td>
#       <td>[Unknown]</td>
#       <td>[  4.0 from 1 vote\n5 Star\n0%\n4 Star\n100%\n3 Star\n0%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#3 in Front Range\n#1,305 in Colorado\n#14,636 Overall\n5 Views Last Month\n1,396 Since Jul 13, 2016, DIFFICULT\n0%\n0%\n0%\n0%\n100%\n0%]</td>
#       <td>6,930'</td>
#       <td>5,527'</td>
#       <td>22.1</td>
#       <td>Point to Point</td>
#       <td>13,247'</td>
#       <td>10,423'</td>
#       <td>11%</td>
#       <td>56%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MF Ranch Creek Road #142</td>
#       <td>[EASY\n 3.0 (1)\nAreas\nCO\nFront Range]</td>
#       <td>[ 3.0 (1)]</td>
#       <td>[Unknown, Views]</td>
#       <td>[  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 Star\n100%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#8 in Front Range\n#2,758 in Colorado\n#33,629 Overall\n2 Views Last Month\n94 Since Sep 26, 2017, EASY\n100%\n0%\n0%\n0%\n0%\n0%]</td>
#       <td>10'</td>
#       <td>580'</td>
#       <td>4.6</td>
#       <td>Point to Point</td>
#       <td>9,560'</td>
#       <td>8,989'</td>
#       <td>2%</td>
#       <td>6%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Lone Pine Creek Trail #951</td>
#       <td>[INTERMEDIATE\n 3.3 (3)\nAreas\nCO\nFront Range]</td>
#       <td>[ 3.3 (3)]</td>
#       <td>[Unknown]</td>
#       <td>[  3.3 from 3 votes\n5 Star\n0%\n4 Star\n33%\n3 Star\n67%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#6 in Front Range\n#2,100 in Colorado\n#25,735 Overall\n13 Views Last Month\n1,307 Since Sep 27, 2018, INTERMEDIATE\n25%\n25%\n25%\n0%\n25%\n0%]</td>
#       <td>1,081'</td>
#       <td>346'</td>
#       <td>9.3</td>
#       <td>Point to Point</td>
#       <td>7,092'</td>
#       <td>6,232'</td>
#       <td>3%</td>
#       <td>17%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>East Blue River Trail #9104</td>
#       <td>[EASY\nBe the first to rate!\nAreas\nCO\nFront Range]</td>
#       <td>[]</td>
#       <td>[Unknown]</td>
#       <td>[  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3 Star\n0%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#11 in Front Range\n#3,982 in Colorado\n#48,630 Overall\n2 Views Last Month\n166 Since Oct 10, 2018, EASY\n100%\n0%\n0%\n0%\n0%\n0%]</td>
#       <td>60'</td>
#       <td>13'</td>
#       <td>1.2</td>
#       <td>Point to Point</td>
#       <td>8,606'</td>
#       <td>8,552'</td>
#       <td>1%</td>
#       <td>4%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Bushee Creek Trail #9104.1</td>
#       <td>[DIFFICULT\nBe the first to rate!\nAreas\nCO\nFront Range]</td>
#       <td>[]</td>
#       <td>[Unknown]</td>
#       <td>[  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3 Star\n0%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#12 in Front Range\n#4,131 in Colorado\n#49,689 Overall\n2 Views Last Month\n122 Since Oct 10, 2018, DIFFICULT\n0%\n0%\n0%\n0%\n100%\n0%]</td>
#       <td>0'</td>
#       <td>699'</td>
#       <td>0.7</td>
#       <td>Point to Point</td>
#       <td>9,210'</td>
#       <td>8,511'</td>
#       <td>19%</td>
#       <td>30%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Elk Horn Trail #925</td>
#       <td>[DIFFICULT\nBe the first to rate!\nAreas\nCO\nFront Range]</td>
#       <td>[]</td>
#       <td>[Unknown]</td>
#       <td>[  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3 Star\n0%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#13 in Front Range\n#4,217 in Colorado\n#50,315 Overall\n3 Views Last Month\n103 Since Oct 17, 2018, DIFFICULT\n0%\n0%\n0%\n0%\n100%\n0%]</td>
#       <td>2,070'</td>
#       <td>22'</td>
#       <td>3.5</td>
#       <td>Point to Point</td>
#       <td>11,351'</td>
#       <td>9,300'</td>
#       <td>11%</td>
#       <td>35%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Piney Creek Trail</td>
#       <td>[EASY\n 3.0 (2)\nAreas\nCO\nFront Range]</td>
#       <td>[ 3.0 (2)]</td>
#       <td>[Unknown]</td>
#       <td>[  3.0 from 2 votes\n5 Star\n0%\n4 Star\n50%\n3 Star\n0%\n2 Star\n50%\n1 Star\n0%, Trail Rankings\n#7 in Front Range\n#2,274 in Colorado\n#26,999 Overall\n6 Views Last Month\n663 Since Mar 29, 2019, EASY\n100%\n0%\n0%\n0%\n0%\n0%]</td>
#       <td>67'</td>
#       <td>442'</td>
#       <td>9.5</td>
#       <td>Point to Point</td>
#       <td>5,996'</td>
#       <td>5,618'</td>
#       <td>1%</td>
#       <td>6%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>OT Loop</td>
#       <td>[INTERMEDIATE\n 4.0 (1)\nAreas\nCO\nFront Range]</td>
#       <td>[ 4.0 (1)]</td>
#       <td>[Leashed, Geological Significance · River/Creek · Wildflowers · Wildlife]</td>
#       <td>[  4.0 from 1 vote\n5 Star\n0%\n4 Star\n100%\n3 Star\n0%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#4 in Front Range\n#1,517 in Colorado\n#17,384 Overall\n2 Views Last Month\n115 Since Apr 6, 2020, INTERMEDIATE\n0%\n0%\n100%\n0%\n0%\n0%]</td>
#       <td>270'</td>
#       <td>248'</td>
#       <td>1.9</td>
#       <td>Loop</td>
#       <td>5,845'</td>
#       <td>5,630'</td>
#       <td>5%</td>
#       <td>13%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Fern Canyon Trail</td>
#       <td>[DIFFICULT\n 4.4 (17)\nAreas\nCO\nFront Range\nBoulder]</td>
#       <td>[ 4.4 (17)]</td>
#       <td>[Leashed, Birding · River/Creek · Views · Wildflowers · Wildlife]</td>
#       <td>[  4.4 from 17 votes\n5 Star\n47%\n4 Star\n41%\n3 Star\n12%\n2 Star\n0%\n1 Star\n0%, Trail Rankings\n#1 in Boulder\n#112 in Colorado\n#605 Overall\n28 Views Last Month\n6,840 Since Dec 16, 2014, DIFFICULT\n0%\n0%\n0%\n0%\n94%\n6%]</td>
#       <td>2,031'</td>
#       <td>0'</td>
#       <td>1.4</td>
#       <td>Point to Point</td>
#       <td>8,413'</td>
#       <td>6,382'</td>
#       <td>28%</td>
#       <td>59%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>North Fork Shanahan Trail</td>
#       <td>[INTERMEDIATE\n 3.8 (8)\nAreas\nCO\nFront Range\nBoulder]</td>
#       <td>[ 3.8 (8)]</td>
#       <td>[Off-leash]</td>
#       <td>[  3.8 from 8 votes\n5 Star\n25%\n4 Star\n38%\n3 Star\n25%\n2 Star\n13%\n1 Star\n0%, Trail Rankings\n#6 in Boulder\n#1,073 in Colorado\n#11,837 Overall\n5 Views Last Month\n1,238 Since Dec 17, 2014, INTERMEDIATE\n0%\n0%\n100%\n0%\n0%\n0%]</td>
#       <td>593'</td>
#       <td>0'</td>
#       <td>1.3</td>
#       <td>Point to Point</td>
#       <td>6,338'</td>
#       <t
