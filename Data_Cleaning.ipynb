# %% [markdown]
# # COMP 4447 Final Project

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# Read the hiking dataset pickle file  
df = pd.read_pickle("hike_project.pkl")

df.tail()
# Out:
#                       Trail Name Trail Length  \
# 3359      Cottonwood Creek Trail          7.4
# 3360             Homestead Trail          2.0
# 3361            Bear Creek Trail         14.9
# 3362  Washington Park Outer Loop          2.6
# 3363    Monument Park Trail West          2.2
#
#                                        Trail Difficulty Trail Rating  \
# 3359  [EASY/INTERMEDIATE\n 3.5 (4)\nAreas\nCO\nFront...   [ 3.5 (4)]
# 3360  [INTERMEDIATE\n 3.0 (1)\nAreas\nCO\nFront Rang...   [ 3.0 (1)]
# 3361  [EASY/INTERMEDIATE\n 4.3 (3)\nAreas\nCO\nFront...   [ 4.3 (3)]
# 3362   [EASY\n 4.0 (2)\nAreas\nCO\nFront Range\nDenver]   [ 4.0 (2)]
# 3363  [EASY\nBe the first to rate!\nAreas\nCO\nFront...           []
#
#      User Rate Number      Trail Type Elev_Up Elev_Down Highest Elevation  \
# 3359       [ 3.5 (4)]  Point to Point    687'       23'            6,923'
# 3360       [ 3.0 (1)]  Point to Point      4'      171'            6,789'
# 3361       [ 4.3 (3)]  Point to Point    806'      277'            5,804'
# 3362       [ 4.0 (2)]            Loop     33'       33'            5,328'
# 3363               []  Point to Point      2'       78'            6,068'
#
#      Lowest Elevation Average Grade Max Grade       Dogs and Features  \
# 3359           6,259'            2%        9%  [Leashed, River/Creek]
# 3360           6,622'            2%        4%               [Leashed]
# 3361           5,269'            1%       11%               [Leashed]
# 3362           5,307'            0%        4%         [Leashed, Lake]
# 3363           5,991'            1%        2%               [Unknown]
#
#                                             Stats Info.
# 3359  [  3.5 from 4 votes\n5 Star\n25%\n4 Star\n25%\...
# 3360  [  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 3361  [  4.3 from 3 votes\n5 Star\n67%\n4 Star\n0%\n...
# 3362  [  4.0 from 2 votes\n5 Star\n50%\n4 Star\n0%\n...
# 3363  [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...

# %%
# adding State, City, Area and Site 
df['State'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[3])
df['City'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[4])
df['Area'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[5] if len(x[0].split('\n')) > 5 else np.nan)
df['Site'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[6] if len(x[0].split('\n')) > 6 else np.nan)

# Specify the desired order of columns
columns = df.columns.tolist()
columns.remove('State')
columns.remove('City')
columns.remove('Area')
columns.remove('Site')
columns = columns[:1] + ['State'] + ['City'] + ['Area'] + ['Site'] + columns[1:]
df = df[columns]

df.sample(10)
# Out:
#                                        Trail Name State         City  \
# 1103  CDT: Gold Hill to Georgia Pass (CO Sec. 28)    CO  Front Range
# 2369                      Plymouth Mountain Trail    CO  Front Range
# 319                           Hogback Ridge Trail    CO  Front Range
# 1537                          Hogback Ridge Trail    CO  Front Range
# 2745                                   3 Bar Loop    CO  Front Range
# 1799  CDT: Gold Hill to Georgia Pass (CO Sec. 28)    CO  Front Range
# 1809                    North Fork Shanahan Trail    CO  Front Range
# 1002                                Chapman Drive    CO  Front Range
# 2256                     East Harvard Gulch Trail    CO  Front Range
# 1130                        Foothills North Trail    CO  Front Range
#
#            Area                    Site Trail Length  \
# 1103        NaN                     NaN         20.4
# 2369  Ken Caryl  Deer Creek Canyon Park          2.3
# 319     Boulder                     NaN          1.8
# 1537    Boulder                     NaN          1.8
# 2745        NaN                     NaN          2.6
# 1799        NaN                     NaN         20.4
# 1809    Boulder                     NaN          1.3
# 1002    Boulder                     NaN          2.6
# 2256     Denver                     NaN          2.6
# 1130    Boulder                     NaN          1.2
#
#                                        Trail Difficulty Trail Rating  \
# 1103  [INTERMEDIATE/DIFFICULT\nBe the first to rate!...           []
# 2369  [INTERMEDIATE/DIFFICULT\n 4.3 (10)\nAreas\nCO\...  [ 4.3 (10)]
# 319   [INTERMEDIATE\n 3.5 (4)\nAreas\nCO\nFront Rang...   [ 3.5 (4)]
# 1537  [INTERMEDIATE\n 3.5 (4)\nAreas\nCO\nFront Rang...   [ 3.5 (4)]
# 2745   [INTERMEDIATE\n 4.0 (2)\nAreas\nCO\nFront Range]   [ 4.0 (2)]
# 1799  [INTERMEDIATE/DIFFICULT\nBe the first to rate!...           []
# 1809  [INTERMEDIATE\n 3.8 (8)\nAreas\nCO\nFront Rang...   [ 3.8 (8)]
# 1002  [EASY/INTERMEDIATE\n 4.2 (5)\nAreas\nCO\nFront...   [ 4.2 (5)]
# 2256   [EASY\n 3.0 (1)\nAreas\nCO\nFront Range\nDenver]   [ 3.0 (1)]
# 1130  [INTERMEDIATE/DIFFICULT\n 2.7 (3)\nAreas\nCO\n...   [ 2.7 (3)]
#
#      User Rate Number      Trail Type Elev_Up Elev_Down Highest Elevation  \
# 1103               []  Point to Point  4,452'    1,865'           11,769'
# 2369      [ 4.3 (10)]  Point to Point    416'      458'            7,132'
# 319        [ 3.5 (4)]  Point to Point    675'      636'            6,399'
# 1537       [ 3.5 (4)]  Point to Point    675'      636'            6,399'
# 2745       [ 4.0 (2)]            Loop    374'      377'            6,068'
# 1799               []  Point to Point  4,452'    1,865'           11,769'
# 1809       [ 3.8 (8)]  Point to Point    593'        0'            6,338'
# 1002       [ 4.2 (5)]  Point to Point    954'       13'            6,746'
# 2256       [ 3.0 (1)]  Point to Point     25'       93'            5,386'
# 1130       [ 2.7 (3)]  Point to Point    174'       91'            5,724'
#
#      Lowest Elevation Average Grade Max Grade  \
# 1103           9,183'            6%       34%
# 2369           6,771'            7%       26%
# 319            5,725'           14%       41%
# 1537           5,725'           14%       41%
# 2745           5,718'            6%       18%
# 1799           9,183'            6%       34%
# 1809           5,745'            9%       13%
# 1002           5,805'            7%       20%
# 2256           5,318'            1%        3%
# 1130           5,550'            4%       16%
#
#                                       Dogs and Features  \
# 1103                                          [Unknown]
# 2369                                   [Leashed, Views]
# 319           [No Dogs, Views · Wildflowers · Wildlife]
# 1537          [No Dogs, Views · Wildflowers · Wildlife]
# 2745                                          [Unknown]
# 1799                                          [Unknown]
# 1809                                        [Off-leash]
# 1002  [Leashed, Birding · Fall Colors · River/Creek ...
# 2256                                          [Unknown]
# 1130        [Off-leash, Views · Wildflowers · Wildlife]
#
#                                             Stats Info.
# 1103  [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 2369  [  4.3 from 10 votes\n5 Star\n33%\n4 Star\n56%...
# 319   [  3.5 from 4 votes\n5 Star\n0%\n4 Star\n50%\n...
# 1537  [  3.5 from 4 votes\n5 Star\n0%\n4 Star\n50%\n...
# 2745  [  4.0 from 2 votes\n5 Star\n0%\n4 Star\n100%\...
# 1799  [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 1809  [  3.8 from 8 votes\n5 Star\n25%\n4 Star\n38%\...
# 1002  [  4.2 from 5 votes\n5 Star\n40%\n4 Star\n40%\...
# 2256  [  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 1130  [  2.7 from 3 votes\n5 Star\n0%\n4 Star\n0%\n3...

# %%
# Data cleaning
# Cleaning Trail rating, User rate number, and renaming User rate number to user review 
if not np.issubdtype(df['Trail Rating'].dtype, np.dtype(str).type):
    df['Trail Rating'] = df['Trail Rating'].astype(str)
df['Trail Rating'] = pd.to_numeric(df['Trail Rating'].str.extract('(\d+\.\d+)')[0], errors='coerce')

if not np.issubdtype(df['User Rate Number'].dtype, np.dtype(str).type):
    df['User Rate Number'] = df['User Rate Number'].astype(str)
df['User Rate Number'] = df['User Rate Number'].str.extract('\((\d+)\)')[0]

df = df.rename(columns={'User Rate Number': 'User Review'})


# Cleaninbg Trail Difficulty and mappping difficulty number 
df['Trail Difficulty'] = df['Trail Difficulty'].apply(lambda x: x[0].split()[0])

# Difficulty mapping
difficulty_map = {
    'EASY': 1,
    'EASY/INTERMEDIATE': 2,
    'INTERMEDIATE': 3,
    'INTERMEDIATE/DIFFICULT': 4,
    'DIFFICULT': 5
}

# Create and sort the Difficulty Number column 
df['Difficulty Number'] = df['Trail Difficulty'].map(difficulty_map)

columns = df.columns.tolist()
columns.remove('Difficulty Number')
columns = columns[:7] + ['Difficulty Number'] + columns[7:]
df = df[columns]

# Cleaning Dog and Features, and sort columns 
df['Features'] = df['Dogs and Features'].apply(lambda x: x[1] if len(x) > 1 else np.nan)

columns = df.columns.tolist()
columns.remove('Features')
columns = columns[:18] + ['Features'] + columns[18:]
df = df[columns]

df['Dogs and Features'] = df['Dogs and Features'].apply(lambda x: x[0].split()[0])
df['Dogs and Features'] = df['Dogs and Features'].replace("Unknown", np.nan)
df = df.rename(columns={'Dogs and Features': 'Dogs'})


df.sample(10)
# Out:
#                        Trail Name State         City  \
# 1608           Pearl Parkway Path    CO  Front Range
# 1459                      OT Loop    CO  Front Range
# 2270            Piney Creek Trail    CO  Front Range
# 2679    North Fork Shanahan Trail    CO  Front Range
# 1670         Plymouth Creek Trail    CO  Front Range
# 1195  South Lateral Moraine Trail    CO  Front Range
# 1009             Goose Creek Path    CO  Front Range
# 1621             Bear Creek Trail    CO  Front Range
# 403              Bear Creek Trail    CO  Front Range
# 648             Fern Canyon Trail    CO  Front Range
#
#                               Area                    Site Trail Length  \
# 1608                       Boulder                     NaN          1.1
# 1459                           NaN                     NaN          1.9
# 2270                           NaN                     NaN          9.5
# 2679                       Boulder                     NaN          1.3
# 1670                     Ken Caryl  Deer Creek Canyon Park          2.4
# 1195  Rocky Mountain National Park                     NaN          2.0
# 1009                       Boulder                     NaN          2.2
# 1621                        Denver                     NaN         14.9
# 403                         Denver                     NaN         14.9
# 648                        Boulder                     NaN          1.4
#
#             Trail Difficulty  Difficulty Number  Trail Rating User Review  \
# 1608                    EASY                  1           2.0           1
# 1459            INTERMEDIATE                  3           4.0           1
# 2270                    EASY                  1           3.0           2
# 2679            INTERMEDIATE                  3           3.8           8
# 1670  INTERMEDIATE/DIFFICULT                  4           3.9          19
# 1195                    EASY                  1           3.0           2
# 1009                    EASY                  1           3.5           2
# 1621       EASY/INTERMEDIATE                  2           4.3           3
# 403        EASY/INTERMEDIATE                  2           4.3           3
# 648                DIFFICULT                  5           4.4          17
#
#           Trail Type Elev_Up Elev_Down Highest Elevation Lowest Elevation  \
# 1608  Point to Point      3'       46'            5,269'           5,226'
# 1459            Loop    270'      248'            5,845'           5,630'
# 2270  Point to Point     67'      442'            5,996'           5,618'
# 2679  Point to Point    593'        0'            6,338'           5,745'
# 1670  Point to Point  1,095'       65'            7,128'           6,038'
# 1195  Point to Point    147'      183'            8,161'           8,044'
# 1009  Point to Point    112'        0'            5,325'           5,213'
# 1621  Point to Point    806'      277'            5,804'           5,269'
# 403   Point to Point    806'      277'            5,804'           5,269'
# 648   Point to Point  2,031'        0'            8,413'           6,382'
#
#      Average Grade Max Grade       Dogs  \
# 1608            1%        2%  Off-leash
# 1459            5%       13%    Leashed
# 2270            1%        6%        NaN
# 2679            9%       13%  Off-leash
# 1670            9%       22%    Leashed
# 1195            3%       11%    Leashed
# 1009            1%        2%    Leashed
# 1621            1%       11%    Leashed
# 403             1%       11%    Leashed
# 648            28%       59%    Leashed
#
#                                                Features  \
# 1608                                                NaN
# 1459  Geological Significance · River/Creek · Wildfl...
# 2270                                                NaN
# 2679                                                NaN
# 1670                     River/Creek · Views · Wildlife
# 1195  Birding · Fall Colors · River/Creek · Views · ...
# 1009  Birding · Fall Colors · River/Creek · Views · ...
# 1621                                                NaN
# 403                                                 NaN
# 648   Birding · River/Creek · Views · Wildflowers · ...
#
#                                             Stats Info.
# 1608  [  2.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 1459  [  4.0 from 1 vote\n5 Star\n0%\n4 Star\n100%\n...
# 2270  [  3.0 from 2 votes\n5 Star\n0%\n4 Star\n50%\n...
# 2679  [  3.8 from 8 votes\n5 Star\n25%\n4 Star\n38%\...
# 1670  [  3.9 from 19 votes\n5 Star\n28%\n4 Star\n39%...
# 1195  [  3.0 from 2 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 1009  [  3.5 from 2 votes\n5 Star\n0%\n4 Star\n50%\n...
# 1621  [  4.3 from 3 votes\n5 Star\n67%\n4 Star\n0%\n...
# 403   [  4.3 from 3 votes\n5 Star\n67%\n4 Star\n0%\n...
# 648   [  4.4 from 17 votes\n5 Star\n47%\n4 Star\n41%...

# %%
# Showing Datatypes 
df.dtypes
# Out:
# Trail Name            object
# State                 object
# City                  object
# Area                  object
# Site                  object
# Trail Length          object
# Trail Difficulty      object
# Difficulty Number      int64
# Trail Rating         float64
# User Review           object
# Trail Type            object
# Elev_Up               object
# Elev_Down             object
# Highest Elevation     object
# Lowest Elevation      object
# Average Grade         object
# Max Grade             object
# Dogs                  object
# Features              object
# Stats Info.           object
# dtype: object

# %%
# Correcting DataTypes 
df['Trail Length'] = df['Trail Length'].astype(float)
df['Elev_Up'] = df['Elev_Up'].str.replace("'", "").str.replace(",", "").astype(float)
df['Elev_Down'] = df['Elev_Down'].str.replace("'", "").str.replace(",", "").astype(float)
df['Highest Elevation'] = df['Highest Elevation'].str.replace("'", "").str.replace(",", "").astype(float)
df['Lowest Elevation'] = df['Lowest Elevation'].str.replace("'", "").str.replace(",", "").astype(float)
df['Average Grade'] = df['Average Grade'].str.strip('%').astype(float) / 100
df['Max Grade'] = df['Max Grade'].str.strip('%').astype(float) / 100
df['User Review'] = df['User Review'].astype("Int64")

df.dtypes
# Out:
# Trail Name            object
# State                 object
# City                  object
# Area                  object
# Site                  object
# Trail Length         float64
# Trail Difficulty      object
# Difficulty Number      int64
# Trail Rating         float64
# User Review            Int64
# Trail Type            object
# Elev_Up              float64
# Elev_Down            float64
# Highest Elevation    float64
# Lowest Elevation     float64
# Average Grade        float64
# Max Grade            float64
# Dogs                  object
# Features              object
# Stats Info.           object
# dtype: object

# %%
df.drop(columns='Stats Info.', inplace=True)

# %%
# Splitting Features Contains into separate Columns
all_features = ['Birding', 'Fall Colors', 'River/Creek', 'Views', 'Wildflowers', 'Spring',
                  'Geological Significance', 'Swimming', 'Lake', 'Wildlife']
for i in all_features:
    df[i] = df['Features'].str.contains(i)

# Replacing all Features NaN values with False 
df['Birding'] = df['Birding'].fillna(False)
df['Fall Colors'] = df['Fall Colors'].fillna(False)
df['River/Creek'] = df['River/Creek'].fillna(False)
df['Views'] = df['Views'].fillna(False)
df['Wildflowers'] = df['Wildflowers'].fillna(False)
df['Wildlife'] = df['Wildlife'].fillna(False)
df['Spring'] = df['Spring'].fillna(False)
df['Geological Significance'] = df['Geological Significance'].fillna(False)
df['Swimming'] = df['Swimming'].fillna(False)
df['Lake'] = df['Lake'].fillna(False)
   
df.iloc[:,18:].sample(25)
# Out:
#                                                Features  Birding  Fall Colors  \
# 282                                                 NaN    False        False
# 2314                                                NaN    False        False
# 1323                                              Views    False        False
# 383   Birding · Fall Colors · River/Creek · Views · ...     True         True
# 2793  Geological Significance · River/Creek · Wildfl...    False        False
# 2037                                                NaN    False        False
# 1860                                                NaN    False        False
# 1716  Birding · Fall Colors · River/Creek · Views · ...     True         True
# 1683                                                NaN    False        False
# 599                                                 NaN    False        False
# 3312                                                NaN    False        False
# 1058  Birding · Fall Colors · Lake · River/Creek · V...     True         True
# 1371                                                NaN    False        False
# 519                                                 NaN    False        False
# 2242                                                NaN    False        False
# 810                                                Lake    False        False
# 1734                                                NaN    False        False
# 1546                                                NaN    False        False
# 2750  Birding · Fall Colors · River/Creek · Views · ...     True         True
# 2167                                                NaN    False        False
# 3197                                                NaN    False        False
# 1922                                                NaN    False        False
# 751                                                 NaN    False        False
# 932                                                 NaN    False        False
# 1889                                Fall Colors · Views    False         True
#
#       River/Creek  Views  Wildflowers  Spring  Geological Significance  \
# 282         False  False        False   False                    False
# 2314        False  False        False   False                    False
# 1323        False   True        False   False                    False
# 383          True   True         True   False                    False
# 2793         True  False         True   False                     True
# 2037        False  False        False   False                    False
# 1860        False  False        False   False                    False
# 1716         True   True         True   False                    False
# 1683        False  False        False   False                    False
# 599         False  False        False   False                    False
# 3312        False  False        False   False                    False
# 1058         True   True        False   False                    False
# 1371        False  False        False   False                    False
# 519         False  False        False   False                    False
# 2242        False  False        False   False                    False
# 810         False  False        False   False                    False
# 1734        False  False        False   False                    False
# 1546        False  False        False   False                    False
# 2750         True   True         True   False                    False
# 2167        False  False        False   False                    False
# 3197        False  False        False   False                    False
# 1922        False  False        False   False                    False
# 751         False  False        False   False                    False
# 932         False  False        False   False                    False
# 1889        False   True        False   False                    False
#
#       Swimming   Lake  Wildlife
# 282      False  False     False
# 2314     False  False     False
# 1323     False  False     False
# 383      False  False      True
# 2793     False  False      True
# 2037     False  False     False
# 1860     False  False     False
# 1716     False  False      True
# 1683     False  False     False
# 599      False  False     False
# 3312     False  False     False
# 1058     False   True      True
# 1371     False  False     False
# 519      False  False     False
# 2242     False  False     False
# 810      False   True     False
# 1734     False  False     False
# 1546     False  False     False
# 2750     False  False      True
# 2167     False  False     False
# 3197     False  False     False
# 1922     False  False     False
# 751      False  False     False
# 932      False  False     False
# 1889     False  False     False

# %%
df.drop(columns='Features', inplace=True)
df.iloc[:,15:].sample(5)
# Out:
#       Average Grade  Max Grade       Dogs  Birding  Fall Colors  River/Creek  \
# 2990           0.00       0.01    Leashed    False        False         True
# 3104           0.01       0.02        NaN    False        False        False
# 1746           0.19       0.30        NaN    False        False        False
# 2131           0.01       0.04  Off-leash    False        False        False
# 1273           0.01       0.11    Leashed    False        False        False
#
#       Views  Wildflowers  Spring  Geological Significance  Swimming   Lake  \
# 2990  False         True   False                    False     False  False
# 3104  False        False   False                    False     False  False
# 1746  False        False   False                    False     False  False
# 2131  False        False   False                    False     False  False
# 1273  False        False   False                    False     False  False
#
#       Wildlife
# 2990     False
# 3104     False
# 1746     False
# 2131     False
# 1273     False

# %%
df.dtypes
# Out:
# Trail Name                  object
# State                       object
# City                        object
# Area                        object
# Site                        object
# Trail Length               float64
# Trail Difficulty            object
# Difficulty Number            int64
# Trail Rating               float64
# User Review                  Int64
# Trail Type                  object
# Elev_Up                    float64
# Elev_Down                  float64
# Highest Elevation          float64
# Lowest Elevation           float64
# Average Grade              float64
# Max Grade                  float64
# Dogs                        object
# Birding                       bool
# Fall Colors                   bool
# River/Creek                   bool
# Views                         bool
# Wildflowers                   bool
# Spring                        bool
# Geological Significance       bool
# Swimming                      bool
# Lake                          bool
# Wildlife                      bool
# dtype: object

# %%
df.to_csv("hike_project_cln_data.csv")
