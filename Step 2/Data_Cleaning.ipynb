# %% [markdown]
# # COMP 4447 Final Project

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# Read the hiking dataset pickle file  
df = pd.read_pickle("hike_project.pkl")

df.tail()
# Out:
#                       Trail Name Trail Length  \
# 3359      Cottonwood Creek Trail          7.4
# 3360             Homestead Trail          2.0
# 3361            Bear Creek Trail         14.9
# 3362  Washington Park Outer Loop          2.6
# 3363    Monument Park Trail West          2.2
#
#                                        Trail Difficulty Trail Rating  \
# 3359  [EASY/INTERMEDIATE\n 3.5 (4)\nAreas\nCO\nFront...   [ 3.5 (4)]
# 3360  [INTERMEDIATE\n 3.0 (1)\nAreas\nCO\nFront Rang...   [ 3.0 (1)]
# 3361  [EASY/INTERMEDIATE\n 4.3 (3)\nAreas\nCO\nFront...   [ 4.3 (3)]
# 3362   [EASY\n 4.0 (2)\nAreas\nCO\nFront Range\nDenver]   [ 4.0 (2)]
# 3363  [EASY\nBe the first to rate!\nAreas\nCO\nFront...           []
#
#      User Rate Number      Trail Type Elev_Up Elev_Down Highest Elevation  \
# 3359       [ 3.5 (4)]  Point to Point    687'       23'            6,923'
# 3360       [ 3.0 (1)]  Point to Point      4'      171'            6,789'
# 3361       [ 4.3 (3)]  Point to Point    806'      277'            5,804'
# 3362       [ 4.0 (2)]            Loop     33'       33'            5,328'
# 3363               []  Point to Point      2'       78'            6,068'
#
#      Lowest Elevation Average Grade Max Grade       Dogs and Features  \
# 3359           6,259'            2%        9%  [Leashed, River/Creek]
# 3360           6,622'            2%        4%               [Leashed]
# 3361           5,269'            1%       11%               [Leashed]
# 3362           5,307'            0%        4%         [Leashed, Lake]
# 3363           5,991'            1%        2%               [Unknown]
#
#                                             Stats Info.
# 3359  [  3.5 from 4 votes\n5 Star\n25%\n4 Star\n25%\...
# 3360  [  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 3361  [  4.3 from 3 votes\n5 Star\n67%\n4 Star\n0%\n...
# 3362  [  4.0 from 2 votes\n5 Star\n50%\n4 Star\n0%\n...
# 3363  [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...

# %%
# adding State, City, Area and Site 
df['State'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[3])
df['City'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[4])
df['Area'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[5] if len(x[0].split('\n')) > 5 else np.nan)
df['Site'] = df['Trail Difficulty'].apply(lambda x: x[0].split('\n')[6] if len(x[0].split('\n')) > 6 else np.nan)

# Specify the desired order of columns
columns = df.columns.tolist()
columns.remove('State')
columns.remove('City')
columns.remove('Area')
columns.remove('Site')
columns = columns[:1] + ['State'] + ['City'] + ['Area'] + ['Site'] + columns[1:]
df = df[columns]

df.sample(10)
# Out:
#                                    Trail Name State         City  \
# 2417             Fern Meadow - Cragmoor Trail    CO  Front Range
# 1747                      Elk Horn Trail #925    CO  Front Range
# 380   East Boulder Community Center Connector    CO  Front Range
# 1310                      Dark Mountain Trail    CO  Front Range
# 596                             Chapman Drive    CO  Front Range
# 2745                               3 Bar Loop    CO  Front Range
# 1875                               3 Bar Loop    CO  Front Range
# 2894                 East Harvard Gulch Trail    CO  Front Range
# 1537                      Hogback Ridge Trail    CO  Front Range
# 1776                Utility Area Access Trail    CO  Front Range
#
#                               Area Site Trail Length  \
# 2417                       Boulder  NaN          1.6
# 1747                           NaN  NaN          3.5
# 380                        Boulder  NaN          0.9
# 1310  Rocky Mountain National Park  NaN          1.7
# 596                        Boulder  NaN          2.6
# 2745                           NaN  NaN          2.6
# 1875                           NaN  NaN          2.6
# 2894                        Denver  NaN          2.6
# 1537                       Boulder  NaN          1.8
# 1776  Rocky Mountain National Park  NaN          2.1
#
#                                        Trail Difficulty Trail Rating  \
# 2417  [INTERMEDIATE/DIFFICULT\n 3.5 (2)\nAreas\nCO\n...   [ 3.5 (2)]
# 1747  [DIFFICULT\nBe the first to rate!\nAreas\nCO\n...           []
# 380   [EASY\n 2.0 (1)\nAreas\nCO\nFront Range\nBoulder]   [ 2.0 (1)]
# 1310  [INTERMEDIATE\n 4.0 (1)\nAreas\nCO\nFront Rang...   [ 4.0 (1)]
# 596   [EASY/INTERMEDIATE\n 4.2 (5)\nAreas\nCO\nFront...   [ 4.2 (5)]
# 2745   [INTERMEDIATE\n 4.0 (2)\nAreas\nCO\nFront Range]   [ 4.0 (2)]
# 1875   [INTERMEDIATE\n 4.0 (2)\nAreas\nCO\nFront Range]   [ 4.0 (2)]
# 2894   [EASY\n 3.0 (1)\nAreas\nCO\nFront Range\nDenver]   [ 3.0 (1)]
# 1537  [INTERMEDIATE\n 3.5 (4)\nAreas\nCO\nFront Rang...   [ 3.5 (4)]
# 1776  [INTERMEDIATE\n 3.0 (2)\nAreas\nCO\nFront Rang...   [ 3.0 (2)]
#
#      User Rate Number      Trail Type Elev_Up Elev_Down Highest Elevation  \
# 2417       [ 3.5 (2)]  Point to Point    850'       16'            6,611'
# 1747               []  Point to Point  2,070'       22'           11,351'
# 380        [ 2.0 (1)]  Point to Point      5'       10'            5,312'
# 1310       [ 4.0 (1)]  Point to Point      1'    1,268'            9,498'
# 596        [ 4.2 (5)]  Point to Point    954'       13'            6,746'
# 2745       [ 4.0 (2)]            Loop    374'      377'            6,068'
# 1875       [ 4.0 (2)]            Loop    374'      377'            6,068'
# 2894       [ 3.0 (1)]  Point to Point     25'       93'            5,386'
# 1537       [ 3.5 (4)]  Point to Point    675'      636'            6,399'
# 1776       [ 3.0 (2)]  Point to Point    657'      258'            8,380'
#
#      Lowest Elevation Average Grade Max Grade  \
# 2417           5,763'           11%       31%
# 1747           9,300'           11%       35%
# 380            5,305'            0%        1%
# 1310           8,230'           14%       62%
# 596            5,805'            7%       20%
# 2745           5,718'            6%       18%
# 1875           5,718'            6%       18%
# 2894           5,318'            1%        3%
# 1537           5,725'           14%       41%
# 1776           7,874'            8%       31%
#
#                                       Dogs and Features  \
# 2417       [Leashed, River/Creek · Views · Wildflowers]
# 1747                                          [Unknown]
# 380                [Leashed, River/Creek · Wildflowers]
# 1310  [No Dogs, Birding · Fall Colors · River/Creek ...
# 596   [Leashed, Birding · Fall Colors · River/Creek ...
# 2745                                          [Unknown]
# 1875                                          [Unknown]
# 2894                                          [Unknown]
# 1537          [No Dogs, Views · Wildflowers · Wildlife]
# 1776  [No Dogs, Birding · Fall Colors · River/Creek ...
#
#                                             Stats Info.
# 2417  [  3.5 from 2 votes\n5 Star\n0%\n4 Star\n50%\n...
# 1747  [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 380   [  2.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 1310  [  4.0 from 1 vote\n5 Star\n0%\n4 Star\n100%\n...
# 596   [  4.2 from 5 votes\n5 Star\n40%\n4 Star\n40%\...
# 2745  [  4.0 from 2 votes\n5 Star\n0%\n4 Star\n100%\...
# 1875  [  4.0 from 2 votes\n5 Star\n0%\n4 Star\n100%\...
# 2894  [  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 1537  [  3.5 from 4 votes\n5 Star\n0%\n4 Star\n50%\n...
# 1776  [  3.0 from 2 votes\n5 Star\n0%\n4 Star\n0%\n3...

# %%
# Data cleaning
# Cleaning Trail rating, User rate number, and renaming User rate number to user review 
if not np.issubdtype(df['Trail Rating'].dtype, np.dtype(str).type):
    df['Trail Rating'] = df['Trail Rating'].astype(str)
df['Trail Rating'] = pd.to_numeric(df['Trail Rating'].str.extract('(\d+\.\d+)')[0], errors='coerce')

if not np.issubdtype(df['User Rate Number'].dtype, np.dtype(str).type):
    df['User Rate Number'] = df['User Rate Number'].astype(str)
df['User Rate Number'] = df['User Rate Number'].str.extract('\((\d+)\)')[0]

df = df.rename(columns={'User Rate Number': 'User Review'})


# Cleaninbg Trail Difficulty and mappping difficulty number 
df['Trail Difficulty'] = df['Trail Difficulty'].apply(lambda x: x[0].split()[0])

# Difficulty mapping
difficulty_map = {
    'EASY': 1,
    'EASY/INTERMEDIATE': 2,
    'INTERMEDIATE': 3,
    'INTERMEDIATE/DIFFICULT': 4,
    'DIFFICULT': 5
}

# Create and sort the Difficulty Number column 
df['Difficulty Number'] = df['Trail Difficulty'].map(difficulty_map)

columns = df.columns.tolist()
columns.remove('Difficulty Number')
columns = columns[:7] + ['Difficulty Number'] + columns[7:]
df = df[columns]

# Cleaning Dog and Features, and sort columns 
df['Features'] = df['Dogs and Features'].apply(lambda x: x[1] if len(x) > 1 else np.nan)

columns = df.columns.tolist()
columns.remove('Features')
columns = columns[:18] + ['Features'] + columns[18:]
df = df[columns]

df['Dogs and Features'] = df['Dogs and Features'].apply(lambda x: x[0].split()[0])
df['Dogs and Features'] = df['Dogs and Features'].replace("Unknown", np.nan)
df = df.rename(columns={'Dogs and Features': 'Dogs'})


df.sample(10)
# Out:
#                       Trail Name State         City       Area  \
# 1239          Happy Canyon Trail    CO  Front Range        NaN
# 1347   South Fork Shanahan Trail    CO  Front Range    Boulder
# 760   Bushee Creek Trail #9104.1    CO  Front Range        NaN
# 553               Bobolink Trail    CO  Front Range    Boulder
# 2483               Red Mesa Loop    CO  Front Range  Ken Caryl
# 1703          Happy Canyon Trail    CO  Front Range        NaN
# 253           Happy Canyon Trail    CO  Front Range        NaN
# 1411                  3 Bar Loop    CO  Front Range        NaN
# 1235          Boulder Creek Path    CO  Front Range    Boulder
# 819          Elk Horn Trail #925    CO  Front Range        NaN
#
#                         Site Trail Length   Trail Difficulty  \
# 1239                     NaN          2.2               EASY
# 1347                     NaN          1.9       INTERMEDIATE
# 760                      NaN          0.7          DIFFICULT
# 553                      NaN          0.5               EASY
# 2483  Deer Creek Canyon Park          2.5       INTERMEDIATE
# 1703                     NaN          2.2               EASY
# 253                      NaN          2.2               EASY
# 1411                     NaN          2.6       INTERMEDIATE
# 1235                     NaN          8.2  EASY/INTERMEDIATE
# 819                      NaN          3.5          DIFFICULT
#
#       Difficulty Number  Trail Rating User Review      Trail Type Elev_Up  \
# 1239                  1           3.0           1  Point to Point    118'
# 1347                  3           3.6           5  Point to Point    672'
# 760                   5           NaN         NaN  Point to Point      0'
# 553                   1           3.5           2  Point to Point     22'
# 2483                  3           3.8           9            Loop    368'
# 1703                  1           3.0           1  Point to Point    118'
# 253                   1           3.0           1  Point to Point    118'
# 1411                  3           4.0           2            Loop    374'
# 1235                  2           3.9          12  Point to Point     53'
# 819                   5           NaN         NaN  Point to Point  2,070'
#
#      Elev_Down Highest Elevation Lowest Elevation Average Grade Max Grade  \
# 1239       11'            5,782'           5,675'            1%        4%
# 1347       37'            6,378'           5,732'            7%       12%
# 760       699'            9,210'           8,511'           19%       30%
# 553         0'            5,304'           5,281'            1%        2%
# 2483      373'            7,425'           7,085'            6%       18%
# 1703       11'            5,782'           5,675'            1%        4%
# 253        11'            5,782'           5,675'            1%        4%
# 1411      377'            6,068'           5,718'            6%       18%
# 1235      559'            5,741'           5,193'            1%       10%
# 819        22'           11,351'           9,300'           11%       35%
#
#            Dogs                                           Features  \
# 1239    Leashed                                                NaN
# 1347  Off-leash                                              Views
# 760         NaN                                                NaN
# 553   Off-leash                  River/Creek · Views · Wildflowers
# 2483    Leashed                                              Views
# 1703    Leashed                                                NaN
# 253     Leashed                                                NaN
# 1411        NaN                                                NaN
# 1235    Leashed  Birding · Fall Colors · River/Creek · Swimming...
# 819         NaN                                                NaN
#
#                                             Stats Info.
# 1239  [  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 1347  [  3.6 from 5 votes\n5 Star\n40%\n4 Star\n0%\n...
# 760   [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...
# 553   [  3.5 from 2 votes\n5 Star\n0%\n4 Star\n50%\n...
# 2483  [  3.8 from 9 votes\n5 Star\n11%\n4 Star\n67%\...
# 1703  [  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 253   [  3.0 from 1 vote\n5 Star\n0%\n4 Star\n0%\n3 ...
# 1411  [  4.0 from 2 votes\n5 Star\n0%\n4 Star\n100%\...
# 1235  [  3.9 from 12 votes\n5 Star\n25%\n4 Star\n42%...
# 819   [  0.0 from 0 votes\n5 Star\n0%\n4 Star\n0%\n3...

# %%
# Showing Datatypes 
df.dtypes
# Out:
# Trail Name            object
# State                 object
# City                  object
# Area                  object
# Site                  object
# Trail Length          object
# Trail Difficulty      object
# Difficulty Number      int64
# Trail Rating         float64
# User Review           object
# Trail Type            object
# Elev_Up               object
# Elev_Down             object
# Highest Elevation     object
# Lowest Elevation      object
# Average Grade         object
# Max Grade             object
# Dogs                  object
# Features              object
# Stats Info.           object
# dtype: object

# %%
# Correcting DataTypes 
df['Trail Length'] = df['Trail Length'].astype(float)
df['Elev_Up'] = df['Elev_Up'].str.replace("'", "").str.replace(",", "").astype(float)
df['Elev_Down'] = df['Elev_Down'].str.replace("'", "").str.replace(",", "").astype(float)
df['Highest Elevation'] = df['Highest Elevation'].str.replace("'", "").str.replace(",", "").astype(float)
df['Lowest Elevation'] = df['Lowest Elevation'].str.replace("'", "").str.replace(",", "").astype(float)
df['Average Grade'] = df['Average Grade'].str.strip('%').astype(float) / 100
df['Max Grade'] = df['Max Grade'].str.strip('%').astype(float) / 100
df['User Review'] = df['User Review'].astype("Int64")

df.dtypes
# Out:
# Trail Name            object
# State                 object
# City                  object
# Area                  object
# Site                  object
# Trail Length         float64
# Trail Difficulty      object
# Difficulty Number      int64
# Trail Rating         float64
# User Review            Int64
# Trail Type            object
# Elev_Up              float64
# Elev_Down            float64
# Highest Elevation    float64
# Lowest Elevation     float64
# Average Grade        float64
# Max Grade            float64
# Dogs                  object
# Features              object
# Stats Info.           object
# dtype: object

# %%
df.drop(columns='Stats Info.', inplace=True)

# %%
# Splitting Features Contains into separate Columns
all_features = ['Birding', 'Fall Colors', 'River/Creek', 'Views', 'Wildflowers', 'Spring',
                  'Geological Significance', 'Swimming', 'Lake', 'Wildlife']
for i in all_features:
    df[i] = df['Features'].str.contains(i)

# Replacing all Features NaN values with False 
df['Birding'] = df['Birding'].fillna(False)
df['Fall Colors'] = df['Fall Colors'].fillna(False)
df['River/Creek'] = df['River/Creek'].fillna(False)
df['Views'] = df['Views'].fillna(False)
df['Wildflowers'] = df['Wildflowers'].fillna(False)
df['Wildlife'] = df['Wildlife'].fillna(False)
df['Spring'] = df['Spring'].fillna(False)
df['Geological Significance'] = df['Geological Significance'].fillna(False)
df['Swimming'] = df['Swimming'].fillna(False)
df['Lake'] = df['Lake'].fillna(False)
   
df.iloc[:,18:].sample(25)
# Out:
#                                                Features  Birding  Fall Colors  \
# 3103                     Views · Wildflowers · Wildlife    False        False
# 845                                 Fall Colors · Views    False         True
# 827   Birding · Fall Colors · River/Creek · Views · ...     True         True
# 1378                                        River/Creek    False        False
# 1505                                                NaN    False        False
# 2031                                                NaN    False        False
# 2018                     River/Creek · Views · Wildlife    False        False
# 385                                                 NaN    False        False
# 991                                                 NaN    False        False
# 2130                                                NaN    False        False
# 912                                                 NaN    False        False
# 522        Fall Colors · River/Creek · Views · Wildlife    False         True
# 2789                                                NaN    False        False
# 156                                         River/Creek    False        False
# 2584                          River/Creek · Wildflowers    False        False
# 526                                                 NaN    False        False
# 721   Birding · Fall Colors · River/Creek · Views · ...     True         True
# 1311  Birding · Fall Colors · River/Creek · Views · ...     True         True
# 2625  Birding · Fall Colors · River/Creek · Views · ...     True         True
# 2058                     Views · Wildflowers · Wildlife    False        False
# 1093                                              Views    False        False
# 2914  Birding · Fall Colors · Lake · River/Creek · V...     True         True
# 1551                                                NaN    False        False
# 3137                                                NaN    False        False
# 2552       Fall Colors · River/Creek · Views · Wildlife    False         True
#
#       River/Creek  Views  Wildflowers  Spring  Geological Significance  \
# 3103        False   True         True   False                    False
# 845         False   True        False   False                    False
# 827          True   True        False   False                    False
# 1378         True  False        False   False                    False
# 1505        False  False        False   False                    False
# 2031        False  False        False   False                    False
# 2018         True   True        False   False                    False
# 385         False  False        False   False                    False
# 991         False  False        False   False                    False
# 2130        False  False        False   False                    False
# 912         False  False        False   False                    False
# 522          True   True        False   False                    False
# 2789        False  False        False   False                    False
# 156          True  False        False   False                    False
# 2584         True  False         True   False                    False
# 526         False  False        False   False                    False
# 721          True   True         True   False                    False
# 1311         True   True         True   False                    False
# 2625         True   True        False   False                    False
# 2058        False   True         True   False                    False
# 1093        False   True        False   False                    False
# 2914         True   True        False   False                    False
# 1551        False  False        False   False                    False
# 3137        False  False        False   False                    False
# 2552         True   True        False   False                    False
#
#       Swimming   Lake  Wildlife
# 3103     False  False      True
# 845      False  False     False
# 827      False  False      True
# 1378     False  False     False
# 1505     False  False     False
# 2031     False  False     False
# 2018     False  False      True
# 385      False  False     False
# 991      False  False     False
# 2130     False  False     False
# 912      False  False     False
# 522      False  False      True
# 2789     False  False     False
# 156      False  False     False
# 2584     False  False     False
# 526      False  False     False
# 721      False  False      True
# 1311     False  False      True
# 2625     False  False      True
# 2058     False  False      True
# 1093     False  False     False
# 2914     False   True      True
# 1551     False  False     False
# 3137     False  False     False
# 2552     False  False      True

# %%
df.drop(columns='Features', inplace=True)
df.iloc[:,15:].sample(5)
# Out:
#       Average Grade  Max Grade       Dogs  Birding  Fall Colors  River/Creek  \
# 155            0.11       0.31    Leashed    False        False         True
# 3302           0.02       0.04    Leashed    False        False        False
# 3306           0.10       0.38    Leashed    False         True         True
# 2409           0.01       0.02  Off-leash    False        False         True
# 1973           0.06       0.34        NaN    False        False        False
#
#       Views  Wildflowers  Spring  Geological Significance  Swimming   Lake  \
# 155    True         True   False                    False     False  False
# 3302  False        False   False                    False     False  False
# 3306   True        False   False                    False     False  False
# 2409   True         True   False                    False     False  False
# 1973  False        False   False                    False     False  False
#
#       Wildlife
# 155      False
# 3302     False
# 3306      True
# 2409     False
# 1973     False

# %%
df.dtypes
# Out:
# Trail Name                  object
# State                       object
# City                        object
# Area                        object
# Site                        object
# Trail Length               float64
# Trail Difficulty            object
# Difficulty Number            int64
# Trail Rating               float64
# User Review                  Int64
# Trail Type                  object
# Elev_Up                    float64
# Elev_Down                  float64
# Highest Elevation          float64
# Lowest Elevation           float64
# Average Grade              float64
# Max Grade                  float64
# Dogs                        object
# Birding                       bool
# Fall Colors                   bool
# River/Creek                   bool
# Views                         bool
# Wildflowers                   bool
# Spring                        bool
# Geological Significance       bool
# Swimming                      bool
# Lake                          bool
# Wildlife                      bool
# dtype: object

# %%
df.to_pickle("hike_project_cln_data.pkl")
